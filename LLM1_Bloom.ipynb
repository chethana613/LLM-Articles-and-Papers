# %% [markdown]
# <a href="https://colab.research.google.com/github/chethana613/LLM-Readings-and-Assignments/blob/main/LLM1_Bloom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #pip install -q transformers

# %%
#! pip show transformers

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
tokenizer1 = AutoTokenizer.from_pretrained("bigscience/bloom-560m")
model1 = AutoModelForCausalLM.from_pretrained("bigscience/bloom-560m")
inputs1 = tokenizer1.encode("Once upon a time ", return_tensors="pt")
outputs1 = model1.generate(inputs1,max_length=200, num_return_sequences=1, temperature=0.7)
generated_text = tokenizer1.decode(outputs1[0], skip_special_tokens=True)
print("bloom-560m:" + str(generated_text))
tokens = tokenizer1.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)
ttr
with torch.no_grad():

    input_ids = tokenizer1.encode(generated_text, return_tensors="pt")
    logits = model1(input_ids).logits


    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))

    perplexity = torch.exp(loss)

print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
tokenizer2 = AutoTokenizer.from_pretrained("bigscience/bloom-1b1")
model2 = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b1")
inputs2 = tokenizer2.encode("Once upon a time ", return_tensors="pt")
outputs2 = model2.generate(inputs2)
generated_text = tokenizer2.decode(outputs2[0], skip_special_tokens=True)
print("bloom-1b1:" + str(tokenizer2.decode(outputs2[0])))
tokens = tokenizer2.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)
ttr
with torch.no_grad():

    input_ids = tokenizer2.encode(generated_text, return_tensors="pt")
    logits = model2(input_ids).logits


    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))

    perplexity = torch.exp(loss)

print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
# Out:
# bloom-1b1:Once upon a time  I was a young man
# I was a young man
# I was a

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
tokenizer3 = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")
model3 = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7")
inputs3 = tokenizer3.encode("Once upon a time ", return_tensors="pt")
outputs3 = model3.generate(inputs3)
generated_text = tokenizer3.decode(outputs3[0], skip_special_tokens=True)
print("bloom-1b7: " + str(generated_text))
tokens = tokenizer3.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)
ttr
with torch.no_grad():

    input_ids = tokenizer3.encode(generated_text, return_tensors="pt")
    logits = model3(input_ids).logits


    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))

    perplexity = torch.exp(loss)

print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1273: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# bloom-1b7:Once upon a time  I was a little girl
# And I was a little girl
# I was

# %% [markdown]
# Adjusting Nucleus sampling to add penality and avoid repetitions

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

tokenizer4 = AutoTokenizer.from_pretrained("bigscience/bloomz-560m")
model4 = AutoModelForCausalLM.from_pretrained("bigscience/bloomz-560m")

inputs4 = tokenizer4.encode("Once upon a time ", return_tensors="pt")

nucleus_sampling = {
    "do_sample": True,
    "max_length": 200,
    "min_length": 200,
    "temperature": 0.7,
    "top_p": 0.92,  # Adjust this threshold for nucleus sampling
    "num_return_sequences": 2
}

outputs4 = model4.generate(inputs4, **nucleus_sampling)
generated_text = tokenizer4.decode(outputs4[0], skip_special_tokens=True)

tokens = tokenizer4.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)
ttr

with torch.no_grad():
    input_ids = tokenizer4.encode(generated_text, return_tensors="pt")
    logits = model4(input_ids).logits
    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))
    perplexity = torch.exp(loss)

print("Generated Text: ", generated_text)
print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
# Out:
# Generated Text:  Once upon a time  when it was possible to make a video game in a computer, the first major game video game video game was developed in the United States. The first major game video game was developed by the company RCA Victor in 1946. In the United States, the first major video game video game was developed by the RCA Victor company. The company RCA Victor was founded in 1946. The company RCA Victor is the company that developed the first major video game video game in the United States. The company RCA Victor was the first major video game video game company in the United States. In the United States, the first major video game video game was developed by the RCA Victor company. The company RCA Victor was founded in 1946. In the United States, the company RCA Victor was the first major video game video game company in the United States. In the United States, the company RCA Victor was the first major video game video game company in the United States
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
tokenizer4 = AutoTokenizer.from_pretrained("bigscience/bloomz-560m")
model4 = AutoModelForCausalLM.from_pretrained("bigscience/bloomz-560m")
inputs4 = tokenizer4.encode("Once upon a time ", return_tensors="pt")
outputs4 = model4.generate(inputs4, min_length = 200, max_length=200, num_return_sequences=2, temperature=0.7)
generated_text = tokenizer4.decode(outputs4[0], skip_special_tokens=True)
print("bloomz-560m: " + str(generated_text))
tokens = tokenizer4.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)
ttr
with torch.no_grad():

    input_ids = tokenizer4.encode(generated_text, return_tensors="pt")
    logits = model4(input_ids).logits


    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))

    perplexity = torch.exp(loss)

print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2be04685f74a> in <cell line: 6>()
#       4 model4 = AutoModelForCausalLM.from_pretrained("bigscience/bloomz-560m")
#       5 inputs4 = tokenizer4.encode("Once upon a time ", return_tensors="pt")
# ----> 6 outputs4 = model4.generate(inputs4, min_length = 200, max_length=200, num_return_sequences=2, temperature=0.7)
#       7 generated_text = tokenizer4.decode(outputs4[0], skip_special_tokens=True)
#       8 print("bloomz-560m: " + str(generated_text))
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

tokenizer4 = AutoTokenizer.from_pretrained("bigscience/bloomz-560m")
model4 = AutoModelForCausalLM.from_pretrained("bigscience/bloomz-560m")

inputs4 = tokenizer4.encode("Once upon a time ", return_tensors="pt")

# Define nucleus sampling parameters
nucleus_sampling = {
    "do_sample": True,
    "max_length": 200,
    "min_length": 200,
    "temperature": 0.7,
    "top_p": 0.92,  # Adjust this threshold for nucleus sampling
    "num_return_sequences": 3
}

outputs4 = model4.generate(inputs4, **nucleus_sampling)
generated_text = tokenizer4.decode(outputs4[0], skip_special_tokens=True)

# Calculate Type-Token Ratio (TTR)
tokens = tokenizer4.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)

# Calculate Perplexity
with torch.no_grad():
    input_ids = tokenizer4.encode(generated_text, return_tensors="pt")
    logits = model4(input_ids).logits
    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))
    perplexity = torch.exp(loss)

print("Generated Text: ", generated_text)
print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
# Out:
# Generated Text:  Once upon a time  when the sun was in its zenith, the sun was rising and the moon was rising again. The earth was moving about as it had been before the sun had been rising. When the moon was rising again, the earth was moving again. And the sun was rising again. The sun was rising again. The moon was rising again. The earth was moving again. And the sun was rising again. The earth was moving again. And the sun was rising again. The sun was rising again. The earth was moving again. And the sun was rising again. The earth was moving again. The sun was rising again. The earth was moving again. The sun was rising again. The earth was moving again. The sun was rising again. The earth was moving again. The sun was rising again. The earth was moving again. The sun was rising again. The earth was moving again. The sun was rising again. The earth was moving again. The sun was rising
# Type-Token Ratio (TTR): 0.15
# Perplexity: 177007.96875

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
tokenizer5 = AutoTokenizer.from_pretrained("bigscience/bloomz-560m")
model5 = AutoModelForCausalLM.from_pretrained("bigscience/bloomz-560m")
inputs5 = tokenizer5.encode("Once upon a time ", return_tensors="pt")
outputs5 = model5.generate(inputs5, max_length=200, num_return_sequences=1)
generated_text = tokenizer5.decode(outputs5[0], skip_special_tokens=True)
print("bloomz-560m: " + str(generated_text))
tokens = tokenizer5.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)
ttr
with torch.no_grad():

    input_ids = tokenizer5.encode(generated_text, return_tensors="pt")
    logits = model5(input_ids).logits


    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))

    perplexity = torch.exp(loss)

print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
# Out:
# Type-Token Ratio (TTR): 0.6
# Perplexity: 15827.8916015625

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
tokenizer6 = AutoTokenizer.from_pretrained("bigscience/bloomz-560m")
model6 = AutoModelForCausalLM.from_pretrained("bigscience/bloomz-560m")
inputs6 = tokenizer6.encode("Once upon a time ", return_tensors="pt")
outputs6 = model6.generate(inputs5, max_length=200, num_return_sequences=1)
generated_text = tokenizer6.decode(outputs6[0], skip_special_tokens=True)
print("bloomz-560m: " + str(generated_text))
tokens = tokenizer6.tokenize(generated_text)
ttr = len(set(tokens)) / len(tokens)
ttr
with torch.no_grad():

    input_ids = tokenizer6.encode(generated_text, return_tensors="pt")
    logits = model6(input_ids).logits


    loss = torch.nn.functional.cross_entropy(logits.view(-1, logits.size(-1)), input_ids.view(-1))

    perplexity = torch.exp(loss)

print("Type-Token Ratio (TTR):", ttr)
print("Perplexity:", perplexity.item())
